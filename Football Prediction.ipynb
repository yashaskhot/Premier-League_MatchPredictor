# %%
#Premier League Match Predictor(Yashas)

# %%
# Data was scraped for 21-22 Season while it was ongoing

# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %%
matches.shape
# Out:
# (1389, 27)

# %%
matches["team"].value_counts()
# Out:
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: round, dtype: int64

# %%
matches["date"] = pd.to_datetime(matches["date"])
#converting date to date time format

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
#setting 0 as away and 1 as home matches

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  notes    sh   sot  dist   fk   pk pkatt season  \
# ...

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
#regex for only getting the hour part and convertint to int type for our model

# %%
matches["day_code"] = matches["date"].dt.dayofweek
#giving number to every day of week(0-mon,1-tues)

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  dist   fk   pk  pkatt season              team  \
# ...

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...   fk   pk  pkatt  season              team  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6123188405797102

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           141  31
# 1            76  28

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.4745762711864407

# %%
#now using rolling averages to improve our predictions

# %%
grouped_matches = matches.groupby("team")

# %%
group=grouped_matches.get_group("Chelsea")
#getting matches chelsea played against

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-14  15:00  Premier League   Matchweek 1  Sat  Home      W  3.0
# 2  2021-08-22  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 3  2021-08-28  17:30  Premier League   Matchweek 3  Sat  Away      D  1.0
# 4  2021-09-11  17:30  Premier League   Matchweek 4  Sat  Home      W  3.0
# 6  2021-09-19  16:30  Premier League   Matchweek 5  Sun  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 51 2021-05-01  17:30  Premier League  Matchweek 34  Sat  Home      W  2.0
# 53 2021-05-08  17:30  Premier League  Matchweek 35  Sat  Away      W  2.0
# 54 2021-05-12  20:15  Premier League  Matchweek 36  Wed  Home      L  0.0
# 56 2021-05-18  20:15  Premier League  Matchweek 37  Tue  Home      W  2.0
# 57 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Away      L  1.0
#
#      ga         opponent  ...   fk   pk  pkatt  season     team venue_code  \
# ...

# %%
def rolling_averages(group, cols, new_cols):
    group=group.sort_values("date")
    rolling_stats=group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group=group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}rolling" for c in cols]

# %%
new_cols
# Out:
# ['gfrolling',
#  'garolling',
#  'shrolling',
#  'sotrolling',
#  'distrolling',
#  'fkrolling',
#  'pkrolling',
#  'pkattrolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2020-10-03  12:30  Premier League   Matchweek 4  Sat  Home      W  4.0
# 6  2020-10-17  15:00  Premier League   Matchweek 5  Sat  Home      D  3.0
# 8  2020-10-24  17:30  Premier League   Matchweek 6  Sat  Away      D  0.0
# 10 2020-10-31  15:00  Premier League   Matchweek 7  Sat  Away      W  3.0
# 12 2020-11-07  17:30  Premier League   Matchweek 8  Sat  Home      W  4.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 44 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Home      W  1.0
# 47 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      L  1.0
# 49 2022-04-09  15:00  Premier League  Matchweek 32  Sat  Away      W  6.0
# 52 2022-04-20  19:45  Premier League  Matchweek 25  Wed  Home      L  2.0
# 53 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Home      W  1.0
#
#      ga        opponent  ...  day_code  target  gfrolling  garolling  \
# ...

# %%
matches_rolling=matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
#getting rolling averages for each match

# %%
matches_rolling=matches_rolling.droplevel('team')

# %%
matches_rolling.index=range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], prediction=preds), index=test.index)
    precision=precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.625

# %%
combined = combined.merge(matches_rolling[["team", "date", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  prediction                     team       date       opponent  \
# 55         0           0                  Arsenal 2022-01-23        Burnley
# 56         1           0                  Arsenal 2022-02-10         Wolves
# 57         1           0                  Arsenal 2022-02-19      Brentford
# 58         1           1                  Arsenal 2022-02-24         Wolves
# 59         1           1                  Arsenal 2022-03-06        Watford
# ...      ...         ...                      ...        ...            ...
# 1312       1           0  Wolverhampton Wanderers 2022-03-13        Everton
# 1313       0           0  Wolverhampton Wanderers 2022-03-18   Leeds United
# 1314       1           0  Wolverhampton Wanderers 2022-04-02    Aston Villa
# 1315       0           0  Wolverhampton Wanderers 2022-04-08  Newcastle Utd
# 1316       0           0  Wolverhampton Wanderers 2022-04-24        Burnley
#
#      result
# 55        D
# 56        W
# 57        W
# ...

# %%
class MissingDict(dict):
    __missing__ = lambda self, key:key
map_values = {
    "Brighton and Hove Albion" : "Brighton",
    "Manchester United" : "Manchester Utd",
    "Newcastle United" : "Newcastle",
    "Tottenham Hotspur" : "Tottenham",
    "West Ham United" : "West Ham",
    "Wolverhampton Wanderers" : "Wolves",
    "Leeds United" : "Leeds",
}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  prediction                     team       date       opponent  \
# 55         0           0                  Arsenal 2022-01-23        Burnley
# 56         1           0                  Arsenal 2022-02-10         Wolves
# 57         1           0                  Arsenal 2022-02-19      Brentford
# 58         1           1                  Arsenal 2022-02-24         Wolves
# 59         1           1                  Arsenal 2022-03-06        Watford
# ...      ...         ...                      ...        ...            ...
# 1312       1           0  Wolverhampton Wanderers 2022-03-13        Everton
# 1313       0           0  Wolverhampton Wanderers 2022-03-18   Leeds United
# 1314       1           0  Wolverhampton Wanderers 2022-04-02    Aston Villa
# 1315       0           0  Wolverhampton Wanderers 2022-04-08  Newcastle Utd
# 1316       0           0  Wolverhampton Wanderers 2022-04-24        Burnley
#
#      result new_team
# 55        D  Arsenal
# ...

# %%
merged = combined.merge(
    combined, left_on=["date", "new_team"], right_on=["date", "opponent"]
)

# %%
merged
# Out:
#      actual_x  prediction_x                   team_x       date  \
# 0           0             0                  Arsenal 2022-01-23
# 1           1             0                  Arsenal 2022-02-10
# 2           1             0                  Arsenal 2022-02-19
# 3           1             1                  Arsenal 2022-02-24
# 4           1             1                  Arsenal 2022-03-06
# ..        ...           ...                      ...        ...
# 228         1             0  Wolverhampton Wanderers 2022-03-13
# 229         0             0  Wolverhampton Wanderers 2022-03-18
# 230         1             0  Wolverhampton Wanderers 2022-04-02
# 231         0             0  Wolverhampton Wanderers 2022-04-08
# 232         0             0  Wolverhampton Wanderers 2022-04-24
#
#         opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0          Burnley        D    Arsenal         0             0
# 1           Wolves        W    Arsenal         0             0
# ...

# %%
print(merged.columns)
# Out:
# Index(['actual_x', 'prediction_x', 'team_x', 'date', 'opponent_x', 'result_x',
#        'new_team_x', 'actual_y', 'prediction_y', 'team_y', 'opponent_y',
#        'result_y', 'new_team_y'],
#       dtype='object')

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] == 0)][
    "actual_x"
].value_counts()
# Out:
# 1    22
# 0    11
# Name: actual_x, dtype: int64

# %%
22/40
# Out:
# 0.55
